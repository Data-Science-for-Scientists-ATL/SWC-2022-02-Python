# %% [markdown]
# #### Use the Pandas library to do statistics on tabular data.

# %%
import pandas as pd

# %% [markdown]
# Read a Comma Separated Values (CSV) data file with pd.read_csv.
# Provide the (relative or absolute) path to the data.

# %%
data = pd.read_csv(filepath_or_buffer='/Users/senaagezo/Desktop/data/gapminder_all.csv')

# %%
print(data)
# Out:
#     continent         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0      Africa         Algeria     2449.008185     3013.976023     2550.816880
# 1      Africa          Angola     3520.610273     3827.940465     4269.276742
# 2      Africa           Benin     1062.752200      959.601080      949.499064
# 3      Africa        Botswana      851.241141      918.232535      983.653976
# 4      Africa    Burkina Faso      543.255241      617.183465      722.512021
# ..        ...             ...             ...             ...             ...
# 137    Europe     Switzerland    14734.232750    17909.489730    20431.092700
# 138    Europe          Turkey     1969.100980     2218.754257     2322.869908
# 139    Europe  United Kingdom     9979.508487    11283.177950    12477.177070
# 140   Oceania       Australia    10039.595640    10949.649590    12217.226860
# 141   Oceania     New Zealand    10556.575660    12247.395320    13175.678000
#
# ...

# %%
data
# Out:
#     continent         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0      Africa         Algeria     2449.008185     3013.976023     2550.816880
# 1      Africa          Angola     3520.610273     3827.940465     4269.276742
# 2      Africa           Benin     1062.752200      959.601080      949.499064
# 3      Africa        Botswana      851.241141      918.232535      983.653976
# 4      Africa    Burkina Faso      543.255241      617.183465      722.512021
# ..        ...             ...             ...             ...             ...
# 137    Europe     Switzerland    14734.232750    17909.489730    20431.092700
# 138    Europe          Turkey     1969.100980     2218.754257     2322.869908
# 139    Europe  United Kingdom     9979.508487    11283.177950    12477.177070
# 140   Oceania       Australia    10039.595640    10949.649590    12217.226860
# 141   Oceania     New Zealand    10556.575660    12247.395320    13175.678000
#
# ...

# %% [markdown]
# ##### Setting the country column as the index for the dataframe. Row headings were initially numbers (0 and 1 in this case).

# %%
data_country = pd.read_csv('gapminder_all.csv', index_col='country')

# %%
data_country
# Out:
#                continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria           Africa     2449.008185     3013.976023     2550.816880
# Angola            Africa     3520.610273     3827.940465     4269.276742
# Benin             Africa     1062.752200      959.601080      949.499064
# Botswana          Africa      851.241141      918.232535      983.653976
# Burkina Faso      Africa      543.255241      617.183465      722.512021
# ...                  ...             ...             ...             ...
# Switzerland       Europe    14734.232750    17909.489730    20431.092700
# Turkey            Europe     1969.100980     2218.754257     2322.869908
# United Kingdom    Europe     9979.508487    11283.177950    12477.177070
# Australia        Oceania    10039.595640    10949.649590    12217.226860
# New Zealand      Oceania    10556.575660    12247.395320    13175.678000
#
#                 gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# ...

# %% [markdown]
# Retrieving a specific column from the data

# %%
data_country = pd.read_csv('gapminder_all.csv',usecols=['country'])

# %%
data_country
# Out:
#             country
# 0           Algeria
# 1            Angola
# 2             Benin
# 3          Botswana
# 4      Burkina Faso
# ..              ...
# 137     Switzerland
# 138          Turkey
# 139  United Kingdom
# 140       Australia
# 141     New Zealand
#
# [142 rows x 1 columns]

# %% [markdown]
# #### Use the DataFrame.info() method to find out more about a dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 38 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   continent       142 non-null    object
#  1   country         142 non-null    object
#  2   gdpPercap_1952  142 non-null    float64
#  3   gdpPercap_1957  142 non-null    float64
#  4   gdpPercap_1962  142 non-null    float64
#  5   gdpPercap_1967  142 non-null    float64
#  6   gdpPercap_1972  142 non-null    float64
#  7   gdpPercap_1977  142 non-null    float64
#  8   gdpPercap_1982  142 non-null    float64
#  9   gdpPercap_1987  142 non-null    float64
#  10  gdpPercap_1992  142 non-null    float64
#  11  gdpPercap_1997  142 non-null    float64
#  12  gdpPercap_2002  142 non-null    float64
#  13  gdpPercap_2007  142 non-null    float64
#  14  lifeExp_1952    142 non-null    float64
#  15  lifeExp_1957    142 non-null    float64
#  16  lifeExp_1962    142 non-null    float64
# ...

# %% [markdown]
# Finding out the column names in the data

# %%
data.columns
# Out:
# Index(['continent', 'country', 'gdpPercap_1952', 'gdpPercap_1957',
#        'gdpPercap_1962', 'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977',
#        'gdpPercap_1982', 'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997',
#        'gdpPercap_2002', 'gdpPercap_2007', 'lifeExp_1952', 'lifeExp_1957',
#        'lifeExp_1962', 'lifeExp_1967', 'lifeExp_1972', 'lifeExp_1977',
#        'lifeExp_1982', 'lifeExp_1987', 'lifeExp_1992', 'lifeExp_1997',
#        'lifeExp_2002', 'lifeExp_2007', 'pop_1952', 'pop_1957', 'pop_1962',
#        'pop_1967', 'pop_1972', 'pop_1977', 'pop_1982', 'pop_1987', 'pop_1992',
#        'pop_1997', 'pop_2002', 'pop_2007'],
#       dtype='object')

# %% [markdown]
# #### Transposing the data

# %%
data.T
# Out:
#                         0            1            2            3    \
# continent            Africa       Africa       Africa       Africa
# country             Algeria       Angola        Benin     Botswana
# gdpPercap_1952  2449.008185  3520.610273    1062.7522   851.241141
# gdpPercap_1957  3013.976023  3827.940465    959.60108   918.232535
# gdpPercap_1962   2550.81688  4269.276742   949.499064   983.653976
# gdpPercap_1967  3246.991771  5522.776375  1035.831411  1214.709294
# gdpPercap_1972  4182.663766  5473.288005  1085.796879  2263.611114
# gdpPercap_1977  4910.416756  3008.647355  1029.161251  3214.857818
# gdpPercap_1982  5745.160213  2756.953672  1277.897616   4551.14215
# gdpPercap_1987  5681.358539  2430.208311   1225.85601   6205.88385
# gdpPercap_1992  5023.216647  2627.845685  1191.207681  7954.111645
# gdpPercap_1997  4797.295051  2277.140884  1232.975292  8647.142313
# gdpPercap_2002  5288.040382  2773.287312  1372.877931  11003.60508
# ...

# %% [markdown]
# ### Use DataFrame.describe() to get summary statistics about data

# %% [markdown]
# DataFrame.describe() gets the summary statistics of only the columns that have numerical data. All other columns are ignored, unless you use the argument include='all'.

# %%
data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count      142.000000      142.000000      142.000000      142.000000
# mean      3725.276046     4299.408345     4725.812342     5483.653047
# std       9321.064786     9869.662202     8667.362525     8095.315431
# min        298.846212      335.997115      355.203227      349.000000
# 25%        864.752389      930.540819     1059.149171     1151.245103
# 50%       1968.528344     2173.220291     2335.439533     2678.334740
# 75%       3913.492777     4876.356362     5709.381428     7075.932943
# max     108382.352900   113523.132900    95458.111760    80894.883260
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count      142.000000      142.000000      142.000000      142.000000
# mean      6770.082815     7313.166421     7518.901673     7900.920218
# std      10614.383403     8362.489150     7733.845006     8288.281304
# ...
